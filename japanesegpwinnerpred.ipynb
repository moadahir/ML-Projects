# %% [markdown]
# ## Predicting the winner of the Japanese Grand Prix 2026

# %%
# !pip install fastf1

import fastf1.plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.makedirs('cache/', exist_ok=True)
fastf1.Cache.enable_cache('cache/')
fastf1.plotting.setup_mpl(color_scheme='fastf1')

# %%
fp1 = fastf1.get_session(2026, 'Japan', 'FP1')
fp2 = fastf1.get_session(2026, 'Japan', 'FP2')
fp3 = fastf1.get_session(2026, 'Japan', 'FP3')
quali = fastf1.get_session(2026, 'Japan', 'Q')

fp1.load()
fp2.load()
fp3.load()
quali.load()

# %%
for session, name in [(fp1,"fp1"), (fp2, 'fp2'), (fp3, 'fp3')]

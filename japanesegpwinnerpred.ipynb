# %% [markdown]
# ## Predicting the winner of the Japanese Grand Prix 2026

# %%
# !pip install fastf1

import fastf1.plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.makedirs('cache/'exist_ok=)

# %% [markdown]
# 1. Import the fastF1 API

# %% [markdown]
# Explain what an API is, the importance of API in this context, and then begin explaining how we will do it. Move on to libraries, what they are and how to import them.

# %%
# !pip install fastf1

import os
import fastf1
cache_path = os.path.expanduser('~/Documents/BuildMLM/cache')
os.makedirs(cache_path, exist_ok=True)
fastf1.Cache.enable_cache(cache_path)

# %% [markdown]
# 2. Loading the required data; in this case the 2 Practice Session for the Australian GP 2026

# %%
os.makedirs('cache/', exist_ok=True)
fastf1.Cache.enable_cache('cache/')

session = fastf1.get_session(2026, 'Australia', 'FP1')
session.load()

session = fastf1.get_session(2026, 'Australia', 'FP2')
session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# ...

# %% [markdown]
# 3. Exploratory data analysis - explain the importance of understanding our data by loading various figures to get a feel for it.
#
# 3.1 Include some visualisation techniques by importing matplotlib, seaborn, and fastf1.plotting.

# %%
session.laps.shape
# Out:
# (544, 31)

# %%
session.laps.describe()
# Out:
#                             Time                    LapTime   LapNumber  \
# count                        544                        458  544.000000
# mean   0 days 00:48:00.551568014  0 days 00:01:39.582021834   14.297794
# min       0 days 00:14:29.320000     0 days 00:01:19.729000    1.000000
# 25%       0 days 00:29:21.721250     0 days 00:01:24.313250    7.000000
# 50%       0 days 00:49:03.714500     0 days 00:01:28.474000   13.500000
# 75%       0 days 01:04:54.917500     0 days 00:01:55.324500   21.250000
# max       0 days 01:18:55.405000     0 days 00:02:29.202000   34.000000
# std    0 days 00:19:18.864191176  0 days 00:00:19.018366427    8.623895
#
#             Stint                 PitOutTime                  PitInTime  \
# count  544.000000                         86                         86
# mean     2.693015  0 days 00:40:20.650313953  0 days 00:51:04.419604651
# min      1.000000     0 days 00:12:49.713000     0 days 00:19:56.286000
# ...

# %%
session.laps.isnull().sum()
# Out:
# Time                    0
# Driver                  0
# DriverNumber            0
# LapTime                86
# LapNumber               0
# Stint                   0
# PitOutTime            458
# PitInTime             458
# Sector1Time             5
# Sector2Time             0
# Sector3Time            65
# Sector1SessionTime      6
# Sector2SessionTime      0
# Sector3SessionTime     65
# SpeedI1                 0
# SpeedI2                 0
# SpeedFL                86
# SpeedST                 0
# IsPersonalBest          0
# Compound                0
# TyreLife                0
# FreshTyre               0
# Team                    0
# LapStartTime            0
# LapStartDate            0
# TrackStatus             0
# Position              544
# Deleted                 0
# DeletedReason           0
# FastF1Generated         0
# IsAccurate              0
# dtype: int64

# %%
session.laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate'],
#       dtype='object')

# %%
session.laps["Driver"].unique()
# Out:
# array(['NOR', 'VER', 'BOR', 'HAD', 'GAS', 'PER', 'ANT', 'ALO', 'LEC',
#        'STR', 'ALB', 'HUL', 'LAW', 'OCO', 'LIN', 'COL', 'HAM', 'SAI',
#        'RUS', 'BOT', 'PIA', 'BEA'], dtype=object)

# %%
session.results
# Out:
#    DriverNumber BroadcastName Abbreviation DriverId         TeamName  \
# 1             1      L NORRIS          NOR                   McLaren
# 3             3  M VERSTAPPEN          VER           Red Bull Racing
# 5             5   G BORTOLETO          BOR                      Audi
# 6             6      I HADJAR          HAD           Red Bull Racing
# 10           10       P GASLY          GAS                    Alpine
# 11           11       S PEREZ          PER                  Cadillac
# 12           12   K ANTONELLI          ANT                  Mercedes
# 14           14      F ALONSO          ALO              Aston Martin
# 16           16     C LECLERC          LEC                   Ferrari
# 18           18      L STROLL          STR              Aston Martin
# 23           23       A ALBON          ALB                  Williams
# 27           27  N HULKENBERG          HUL                      Audi
# 30           30      L LAWSON          LAW              Racing Bulls
# ...

# %%
session.laps.info()
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                544 non-null    timedelta64[ns]
#  1   Driver              544 non-null    object
#  2   DriverNumber        544 non-null    object
#  3   LapTime             458 non-null    timedelta64[ns]
#  4   LapNumber           544 non-null    float64
#  5   Stint               544 non-null    float64
#  6   PitOutTime          86 non-null     timedelta64[ns]
#  7   PitInTime           86 non-null     timedelta64[ns]
#  8   Sector1Time         539 non-null    timedelta64[ns]
#  9   Sector2Time         544 non-null    timedelta64[ns]
#  10  Sector3Time         479 non-null    timedelta64[ns]
#  11  Sector1SessionTime  538 non-null    timedelta64[ns]
#  12  Sector2SessionTime  544 non-null    timedelta64[ns]
#  13  Sector3SessionTime  479 non-null    timedelta64[ns]
# ...
